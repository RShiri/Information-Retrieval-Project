# %%
# download nltk stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Install a particular version of `google-cloud-storage` because (oddly enough)
# the  version on Colab and GCP is old. A dependency error below is okay.
# !pip install -q google-cloud-storage==1.43.0
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 3.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.21.0 requires google-cloud-storage<4.0.0,>=2.18.0, but you have google-cloud-storage 1.43.0 which is incompatible.
# bigframes 2.30.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.43.0 which is incompatible.

# %%
# authenticate below for Google Storage access as needed
from google.colab import auth
auth.authenticate_user()

# %%
# Download all required folders from your bucket
# !gsutil -m cp -r gs://assignment3ramshiri209478593/text_stemmed .
# !gsutil -m cp -r gs://assignment3ramshiri209478593/title_stemmed .
# !gsutil -m cp -r gs://assignment3ramshiri209478593/anchor_stemmed .
# !gsutil -m cp -r gs://assignment3ramshiri209478593/id_title .
# !gsutil -m cp -r gs://assignment3ramshiri209478593/pr .
# !gsutil -m cp -r gs://assignment3ramshiri209478593/pv .
# !gsutil -m cp -r gs://assignment3ramshiri209478593/og_anchor_idx .
# !gsutil -m cp -r gs://assignment3ramshiri209478593/og_text_idx .
# !gsutil -m cp -r gs://assignment3ramshiri209478593/og_title_idx .
# Out:
# CommandException: No URLs matched: gs://assignment3ramshiri209478593/text_stemmed
# CommandException: 1 file/object could not be transferred.
# CommandException: No URLs matched: gs://assignment3ramshiri209478593/title_stemmed
# CommandException: 1 file/object could not be transferred.
# CommandException: No URLs matched: gs://assignment3ramshiri209478593/anchor_stemmed
# CommandException: 1 file/object could not be transferred.
# Copying gs://assignment3ramshiri209478593/id_title/even_id_title_dict.pkl...
# Copying gs://assignment3ramshiri209478593/id_title/uneven_id_title_dict.pkl...
# \ [2/2 files][168.9 MiB/168.9 MiB] 100% Done
# Operation completed over 2 objects/168.9 MiB.
# Copying gs://assignment3ramshiri209478593/pr/_SUCCESS...
# Copying gs://assignment3ramshiri209478593/pr/part-00000-77ff440d-0296-435b-984a-d8bb8261ffcb-c000.csv.gz...
# CommandException: No URLs matched: gs://assignment3ramshiri209478593/pv
# CommandException: 1 file/object could not be transferred.
# CommandException: No URLs matched: gs://assignment3ramshiri209478593/og_anchor_idx
# CommandException: 1 file/object could not be transferred.
# CommandException: No URLs matched: gs://assignment3ramshiri209478593/og_text_idx
# CommandException: 1 file/object could not be transferred.
# CommandException: No URLs matched: gs://assignment3ramshiri209478593/og_title_idx
# CommandException: 1 file/object could not be transferred.

# %%
# !gsutil -m cp -r gs://assignment3ramshiri209478593/postings_gcp .
# Out:
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_027.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_028.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/0_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/100_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/101_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/102_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/103_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_027.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_028.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_029.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_030.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_032.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_031.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_033.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_034.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_035.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_036.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/104_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/105_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/106_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/107_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/108_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/109_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/10_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_027.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/110_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/111_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_027.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/112_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_027.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_028.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/113_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/114_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/115_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/116_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/117_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/118_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/119_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_027.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_028.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/11_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/120_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/121_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/122_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/123_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_027.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_028.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_029.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_030.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/12_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_020.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_021.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_022.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_023.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_024.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_025.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_026.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_027.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/13_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_014.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_015.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_016.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_018.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_017.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_019.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/14_posting_locs.pickle...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_000.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_001.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_002.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_003.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_004.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_005.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_006.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_007.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_008.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_009.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_010.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_011.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_012.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_013.bin...
# Copying gs://assignment3ramshiri209478593/postings_gcp/15_014.bin...

# %% [markdown]
# # Run the app

# %%
# you need to upload your implementation of search_app.py
import search_frontend as se
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3258105218.py in <cell line: 0>()
#       1 # you need to upload your implementation of search_app.py
# ----> 2 import search_frontend as se
#
# ModuleNotFoundError: No module named 'search_frontend'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# uncomment the code below and execute to reload the module when you make
# changes to search_frontend.py (after you upload again).
import importlib
importlib.reload(se)

# %%
# find Colab's public URL
from google.colab.output import eval_js
server_url = eval_js("google.colab.kernel.proxyPort(5000)")
print(f"""Test your search engine by navigating to
{server_url}search?query=hello+world
This URL is only accessible from the same browser session. In other words, this
will not be accessible from a different machine, browser, or incognito session.
""")

# Uncomment the following line of code to run the frontend in the main
# process and wait for HTTP requests (colab will hang). The debug parameter
# lets you see incoming requests and get debug print outs if exceptions occur.
# se.run(debug=False, use_reloader=False)

# Alternatively, the next few lines run the frontend in a background process.
# Just don't forget to terminate the process when you update your search engine
# or want to reload it.
import multiprocessin, time
proc = multiprocessing.Process(target=se.run,
                               kwargs={"debug": True, "use_reloader": False,
                                       "host": "0.0.0.0", "port": 5000})
proc.start()

time.sleep(1) # give Flask time to boot

from google.colab.output import eval_js
server_url = eval_js("google.colab.kernel.proxyPort(5000)")

print(f"Open this URL:\n{server_url}/search?query=hello+world")
# Use proc.terminate() to stop the process

# %% [markdown]
# # Testing your app
#
# Once your app is running you can query it. You can simply do that by clicking on the URL printed above (the one looking like https://XXXXX-5000-colab.googleusercontent.com/search?query=hello+world or by issuing an HTTP request through code (from colab).
#
# The code below shows how to issue a query from python. This is also how our testing code will issue queries to your search engine, so make sure to test your search engine this way after you deploy it to GCP and before submission. Command line instructions for deploying your search engine to GCP are available at `run_frontend_in_gcp.sh`. Note that we will not only issue training queries to your search engine, but also test queries, i.e. queries that you've never seen before.

# %%
import json

with open('queries_train.json', 'rt') as f:
  queries = json.load(f)

# %%
def average_precision(true_list, predicted_list, k=40):
    true_set = frozenset(true_list)
    predicted_list = predicted_list[:k]
    precisions = []
    for i,doc_id in enumerate(predicted_list):
        if doc_id in true_set:
            prec = (len(precisions)+1) / (i+1)
            precisions.append(prec)
    if len(precisions) == 0:
        return 0.0
    return round(sum(precisions)/len(precisions),3)

# %%
def precision_at_k(true_list, predicted_list, k):
    true_set = frozenset(true_list)
    predicted_list = predicted_list[:k]
    if len(predicted_list) == 0:
        return 0.0
    return round(len([1 for doc_id in predicted_list if doc_id in true_set]) / len(predicted_list), 3)
def recall_at_k(true_list, predicted_list, k):
    true_set = frozenset(true_list)
    predicted_list = predicted_list[:k]
    if len(true_set) < 1:
        return 1.0
    return round(len([1 for doc_id in predicted_list if doc_id in true_set]) / len(true_set), 3)
def f1_at_k(true_list, predicted_list, k):
    p = precision_at_k(true_list, predicted_list, k)
    r = recall_at_k(true_list, predicted_list, k)
    if p == 0.0 or r == 0.0:
        return 0.0
    return round(2.0 / (1.0/p + 1.0/r), 3)
def results_quality(true_list, predicted_list):
    p5 = precision_at_k(true_list, predicted_list, 5)
    f1_30 = f1_at_k(true_list, predicted_list, 30)
    if p5 == 0.0 or f1_30 == 0.0:
        return 0.0
    return round(2.0 / (1.0/p5 + 1.0/f1_30), 3)

assert precision_at_k(range(10), [1,2,3] , 2) == 1.0
assert recall_at_k(   range(10), [10,5,3], 2) == 0.1
assert precision_at_k(range(10), []      , 2) == 0.0
assert precision_at_k([],        [1,2,3],  5) == 0.0
assert recall_at_k(   [],        [10,5,3], 2) == 1.0
assert recall_at_k(   range(10), [],       2) == 0.0
assert f1_at_k(       [],        [1,2,3],  5) == 0.0
assert f1_at_k(       range(10), [],       2) == 0.0
assert f1_at_k(       range(10), [0,1,2],  2) == 0.333
assert f1_at_k(       range(50), range(5), 30) == 0.182
assert f1_at_k(       range(50), range(10), 30) == 0.333
assert f1_at_k(       range(50), range(30), 30) == 0.75
assert results_quality(range(50), range(5))  == 0.308
assert results_quality(range(50), range(10)) == 0.5
assert results_quality(range(50), range(30)) == 0.857
assert results_quality(range(50), [-1]*5 + list(range(5,30))) == 0.0

# %%
import requests
from time import time
# In GCP the public URL for your engine should look like this:
# url = 'http://35.232.59.3:8080'
# In colab, we are going to send HTTP requests to localhost (127.0.0.1)
# and direct them to port where the server is listening (5000).
url = 'http://34.9.174.234:8080'

qs_res = []
for q, true_wids in queries.items():
  duration, ap = None, None
  t_start = time()
  try:
    res = requests.get(url + '/search', {'query': q}, timeout=35)
    duration = time() - t_start
    if res.status_code == 200:
      pred_wids, _ = zip(*res.json())
      rq = results_quality(true_wids, pred_wids)
  except:
    pass

  qs_res.append((q, duration, rq))

# %%
# Printing results taken
for q, duration, rq in qs_res:
    print(f"Query: {q:20} | Time: {duration:.2f}s | Quality (AP): {rq:.3f}")

# (Mean Average Precision)
if qs_res:
    avg_quality = sum([x[2] for x in qs_res]) / len(qs_res)
    avg_time = sum([x[1] for x in qs_res]) / len(qs_res)
    print("\n" + "="*30)
    print(f"MEAN AVERAGE PRECISION (MAP): {avg_quality:.3f}")
    print(f"AVERAGE RESPONSE TIME: {avg_time:.2f}s")
    print("="*30)
# Out:
# Query: Mount Everest climbing expeditions | Time: 0.89s | Quality (AP): 0.667
# Query: Great Fire of London 1666 | Time: 7.26s | Quality (AP): 0.606
# Query: Nanotechnology materials science | Time: 0.33s | Quality (AP): 0.000
# Query: Fossil fuels climate change | Time: 0.74s | Quality (AP): 0.507
# Query: DNA double helix discovery | Time: 0.46s | Quality (AP): 0.417
# Query: Printing press invention Gutenberg | Time: 2.59s | Quality (AP): 0.506
# Query: Ancient Egypt pyramids pharaohs | Time: 1.28s | Quality (AP): 0.343
# Query: Gothic literature Mary Shelley | Time: 0.61s | Quality (AP): 0.206
# Query: Robotics automation industry | Time: 0.41s | Quality (AP): 0.283
# Query: Television invention broadcast media | Time: 2.89s | Quality (AP): 0.000
# Query: Wright brothers first flight | Time: 3.37s | Quality (AP): 0.303
# Query: Steam locomotive transportation history | Time: 1.53s | Quality (AP): 0.224
# Query: Currency history gold standard | Time: 3.59s | Quality (AP): 0.081
# Query: Renaissance art Leonardo da Vinci | Time: 2.84s | Quality (AP): 0.338
# Query: Shakespeare plays Elizabethan theatre | Time: 2.67s | Quality (AP): 0.268
# Query: Solar eclipse astronomy observation | Time: 0.47s | Quality (AP): 0.227
# Query: Renaissance architecture Florence Italy | Time: 0.33s | Quality (AP): 0.227
# Query: Impressionism Monet Renoir | Time: 0.57s | Quality (AP): 0.606
# Query: Samurai code Bushido Japan | Time: 2.67s | Quality (AP): 0.538
# Query: Fossil record paleontology evidence | Time: 4.05s | Quality (AP): 0.288
# Query: Silk Road trade cultural exchange | Time: 4.11s | Quality (AP): 0.309
# Query: Industrial Revolution steam engines | Time: 0.53s | Quality (AP): 0.046
# Query: Green Revolution agriculture yield | Time: 2.60s | Quality (AP): 0.173
# Query: Quantum computing future technology | Time: 0.40s | Quality (AP): 0.000
# Query: Viking exploration North America | Time: 7.99s | Quality (AP): 0.000
# Query: Roman aqueducts engineering innovation | Time: 1.15s | Quality (AP): 0.248
# Query: Coffee history Ethiopia trade | Time: 1.85s | Quality (AP): 0.000
# Query: Stonehenge prehistoric monument | Time: 0.58s | Quality (AP): 0.000
# Query: Photography invention Daguerre | Time: 0.34s | Quality (AP): 0.000
# Query: Ballet origins France Russia | Time: 2.29s | Quality (AP): 0.000
#
# ==============================
# MEAN AVERAGE PRECISION (MAP): 0.247
# AVERAGE RESPONSE TIME: 2.04s
# ==============================

# %%
import pickle
import os

# יצירת מילונים ריקים כדי שהשרת לא יקרוס
# BackendClass שכתבנו יודע להתמודד עם זה ויחזיר את ה-ID ככותרת
dummy_dict = {}

print("Creating dummy dictionary files...")

with open('even_id_title_dict.pkl', 'wb') as f:
    pickle.dump(dummy_dict, f)

with open('uneven_id_title_dict.pkl', 'wb') as f:
    pickle.dump(dummy_dict, f)

# העלאה לבאקט שלך
bucket_name = 'assignment3ramshiri209478593'
print(f"Uploading to bucket: {bucket_name}...")

os.system(f"gsutil cp even_id_title_dict.pkl gs://{bucket_name}/postings_gcp/")
os.system(f"gsutil cp uneven_id_title_dict.pkl gs://{bucket_name}/postings_gcp/")

print("Files uploaded successfully! Now go to the server and download them.")
# Out:
# Creating dummy dictionary files...
# Uploading to bucket: assignment3ramshiri209478593...
# Files uploaded successfully! Now go to the server and download them.
